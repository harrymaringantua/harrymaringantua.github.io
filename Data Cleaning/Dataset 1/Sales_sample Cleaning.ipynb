# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Harry/Portofolio/My Project/Data Cleaning/Sales_sample.csv")

# %%
data.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES         ORDERDATE  \
# 0               30      95.70                2  2871.00    2/24/2003 0:00
# 1               34      81.35                5  2765.90  05-07-2003 00:00
# 2               41      94.74                2  3884.34  07-01-2003 00:00
# 3               45      83.26                6  3746.70    8/25/2003 0:00
# 4               49     100.00               14  5205.27  10-10-2003 00:00
#
#     STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  Unnamed: 14  \
# 0  Shipped       1         2     2003  Motorcycles  ...          NaN
# 1  Shipped       2         5     2003  Motorcycles  ...          NaN
# 2  Shipped       3         7     2003  Motorcycles  ...          NaN
# 3  Shipped       3         8     2003  Motorcycles  ...          NaN
# 4  Shipped       4        10     2003  Motorcycles  ...          NaN
#
#   Unnamed: 15           CITY  Unnamed: 17  Unnamed: 18  COUNTRY Unnamed: 20  \
# ...

# %%
data.columns
# Out:
# Index(['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES', 'ORDERDATE',
#        'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'CITY', 'Unnamed: 17', 'Unnamed: 18', 'COUNTRY',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'DEALSIZE'],
#       dtype='object')

# %%
data.drop(columns = ['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
       'Unnamed: 15', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22'], inplace =True)

# %%
data.columns
# Out:
# Index(['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES', 'ORDERDATE',
#        'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CITY', 'COUNTRY', 'DEALSIZE'],
#       dtype='object')

# %%
data
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES         ORDERDATE  \
# 0                  30      95.70                2  2871.00    2/24/2003 0:00
# 1                  34      81.35                5  2765.90  05-07-2003 00:00
# 2                  41      94.74                2  3884.34  07-01-2003 00:00
# 3                  45      83.26                6  3746.70    8/25/2003 0:00
# 4                  49     100.00               14  5205.27  10-10-2003 00:00
# ...               ...        ...              ...      ...               ...
# 2818               20     100.00               15  2244.40  12-02-2004 00:00
# 2819               29     100.00                1  3978.51    1/31/2005 0:00
# 2820               43     100.00                4  5417.57  03-01-2005 00:00
# 2821               34      62.24                1  2116.16    3/28/2005 0:00
# 2822               47      65.52                9  3079.44  05-06-2005 00:00
#
# ...

# %%
#checking missing Value
data.isnull().sum()
# Out:
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# ORDERDATE          0
# STATUS             0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# PRODUCTLINE        0
# MSRP               0
# PRODUCTCODE        0
# CITY               0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
data.describe()
# Out:
#        QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER         SALES  \
# count      2823.000000  2823.000000      2823.000000   2823.000000
# mean         35.092809    83.658544         6.466171   3553.889072
# std           9.741443    20.174277         4.225841   1841.865106
# min           6.000000    26.880000         1.000000    482.130000
# 25%          27.000000    68.860000         3.000000   2203.430000
# 50%          35.000000    95.700000         6.000000   3184.800000
# 75%          43.000000   100.000000         9.000000   4508.000000
# max          97.000000   100.000000        18.000000  14082.800000
#
#             QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count  2823.000000  2823.000000  2823.00000  2823.000000
# mean      2.717676     7.092455  2003.81509   100.715551
# std       1.203878     3.656633     0.69967    40.187912
# min       1.000000     1.000000  2003.00000    33.000000
# 25%       2.000000     4.000000  2003.00000    68.000000
# ...

# %%
for i in data["QUANTITYORDERED"]:
    if i == 0:
        print(True)

# %%
data.loc[data["QUANTITYORDERED"] == 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE]
# Index: []

# %%
data.loc[data["QUANTITYORDERED"] % 1 != 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE]
# Index: []

# %%
data.set_index("QUANTITYORDERED", inplace = True)

# %%
data
# Out:
#                  PRICEEACH  ORDERLINENUMBER    SALES         ORDERDATE  \
# QUANTITYORDERED
# 30                   95.70                2  2871.00    2/24/2003 0:00
# 34                   81.35                5  2765.90  05-07-2003 00:00
# 41                   94.74                2  3884.34  07-01-2003 00:00
# 45                   83.26                6  3746.70    8/25/2003 0:00
# 49                  100.00               14  5205.27  10-10-2003 00:00
# ...                    ...              ...      ...               ...
# 20                  100.00               15  2244.40  12-02-2004 00:00
# 29                  100.00                1  3978.51    1/31/2005 0:00
# 43                  100.00                4  5417.57  03-01-2005 00:00
# 34                   62.24                1  2116.16    3/28/2005 0:00
# 47                   65.52                9  3079.44  05-06-2005 00:00
#
#                    STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# QUANTITYORDERED
# ...

# %%
data.loc[35]
# Out:
#                  PRICEEACH  ORDERLINENUMBER    SALES         ORDERDATE  \
# QUANTITYORDERED
# 35                  100.00                3  6075.30    1/29/2004 0:00
# 35                   65.63                4  2297.05    1/20/2005 0:00
# 35                  100.00                2  5818.40    7/20/2004 0:00
# 35                  100.00               13  4639.25  11-04-2003 00:00
# 35                  100.00                1  4850.30  11-03-2004 00:00
# ...                    ...              ...      ...               ...
# 35                   82.43                2  2885.05    3/20/2004 0:00
# 35                   90.37                8  3162.95  05-07-2004 00:00
# 35                   71.07                7  2487.45    6/24/2004 0:00
# 35                  100.00               11  4277.35   12/17/2004 0:00
# 35                   59.51                6  2082.85   10/14/2004 0:00
#
#                     STATUS  QTR_ID  MONTH_ID  YEAR_ID   PRODUCTLINE  MSRP  \
# QUANTITYORDERED
# ...

# %%
data.reset_index(inplace = True)

# %%
data.loc[data["PRICEEACH"]==0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE]
# Index: []

# %%
data.loc[data["ORDERLINENUMBER"] == 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, ORDERDATE, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE]
# Index: []

# %%
new = data["ORDERDATE"].str.split(" ", n=1, expand = True)

# %%
new
# Out:
#                0      1
# 0      2/24/2003   0:00
# 1     05-07-2003  00:00
# 2     07-01-2003  00:00
# 3      8/25/2003   0:00
# 4     10-10-2003  00:00
# ...          ...    ...
# 2818  12-02-2004  00:00
# 2819   1/31/2005   0:00
# 2820  03-01-2005  00:00
# 2821   3/28/2005   0:00
# 2822  05-06-2005  00:00
#
# [2823 rows x 2 columns]

# %%
data["Order_Date"] = new[0]
data["Time"] = new[1]

# %%
data.Time.unique()
# Out:
# array(['0:00', '00:00'], dtype=object)

# %%
data.drop("Time", inplace = True, axis = 1)

# %%
data.drop("ORDERDATE",inplace = True, axis = 1)

# %%
data.Order_Date.describe()
# Out:
# count           2823
# unique           252
# top       11/14/2003
# freq              38
# Name: Order_Date, dtype: object

# %%
data.Order_Date.replace({'-' : '/'}, regex = True)
# Out:
# 0        2/24/2003
# 1       05/07/2003
# 2       07/01/2003
# 3        8/25/2003
# 4       10/10/2003
#            ...
# 2818    12/02/2004
# 2819     1/31/2005
# 2820    03/01/2005
# 2821     3/28/2005
# 2822    05/06/2005
# Name: Order_Date, Length: 2823, dtype: object

# %%
data.Order_Date.apply(pd.to_datetime)
# Out:
# 0      2003-02-24
# 1      2003-05-07
# 2      2003-07-01
# 3      2003-08-25
# 4      2003-10-10
#           ...
# 2818   2004-12-02
# 2819   2005-01-31
# 2820   2005-03-01
# 2821   2005-03-28
# 2822   2005-05-06
# Name: Order_Date, Length: 2823, dtype: datetime64[ns]

# %%
data.STATUS.unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
data.QTR_ID.unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
data.loc[data["QTR_ID"] % 1 != 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE, Order_Date]
# Index: []

# %%
data.loc[data["MONTH_ID"]%1 != 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE, Order_Date]
# Index: []

# %%
data.loc[data["YEAR_ID"]%1 != 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE, Order_Date]
# Index: []

# %%
data.PRODUCTLINE.unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
data.loc[data["MSRP"]%1 != 0]
# Out:
# Empty DataFrame
# Columns: [QUANTITYORDERED, PRICEEACH, ORDERLINENUMBER, SALES, STATUS, QTR_ID, MONTH_ID, YEAR_ID, PRODUCTLINE, MSRP, PRODUCTCODE, CITY, COUNTRY, DEALSIZE, Order_Date]
# Index: []

# %%
data.PRODUCTCODE.unique()
# Out:
# array(['S10_1678', 'S10_1949', 'S10_2016', 'S10_4698', 'S10_4757',
#        'S10_4962', 'S12_1099', 'S12_1108', 'S12_1666', 'S12_2823',
#        'S12_3148', 'S12_3380', 'S12_3891', 'S12_3990', 'S12_4473',
#        'S12_4675', 'S18_1097', 'S18_1129', 'S18_1342', 'S18_1367',
#        'S18_1589', 'S18_1662', 'S18_1749', 'S18_1889', 'S18_1984',
#        'S18_2238', 'S18_2248', 'S18_2319', 'S18_2325', 'S18_2432',
#        'S18_2581', 'S18_2625', 'S18_2795', 'S18_2870', 'S18_2949',
#        'S18_2957', 'S18_3029', 'S18_3136', 'S18_3140', 'S18_3232',
#        'S18_3259', 'S18_3278', 'S18_3320', 'S18_3482', 'S18_3685',
#        'S18_3782', 'S18_3856', 'S18_4027', 'S18_4409', 'S18_4522',
#        'S18_4600', 'S18_4668', 'S18_4721', 'S18_4933', 'S24_1046',
#        'S24_1444', 'S24_1578', 'S24_1628', 'S24_1785', 'S24_1937',
#        'S24_2000', 'S24_2011', 'S24_2022', 'S24_2300', 'S24_2360',
#        'S24_2766', 'S24_2840', 'S24_2841', 'S24_2887', 'S24_2972',
# ...

# %%
data.CITY.unique()
# Out:
# array(['NYC', 'Reims', 'Paris', 'Pasadena', 'San Francisco', 'Burlingame',
#        'Lille', 'Bergen', 'Melbourne', 'Newark', 'Bridgewater', 'Nantes',
#        'Cambridge', 'Helsinki', 'Stavern', 'Allentown', 'Salzburg',
#        'Chatswood', 'New Bedford', 'Liverpool', 'Madrid', 'Lule',
#        'Singapore', 'South Brisbane', 'Philadelphia', 'Lyon', 'Vancouver',
#        'Burbank', 'New Haven', 'Minato-ku', 'Torino', 'Boras',
#        'Versailles', 'San Rafael', 'Nashua', 'Brickhaven', 'North Sydney',
#        'Montreal', 'Osaka', 'White Plains', 'Kobenhavn', 'London',
#        'Toulouse', 'Barcelona', 'Los Angeles', 'San Diego', 'Bruxelles',
#        'Tsawassen', 'Boston', 'Cowes', 'Oulu', 'San Jose', 'Graz',
#        'Makati City', 'Marseille', 'Koln', 'Gensve', 'Reggio Emilia',
#        'Frankfurt', 'Espoo', 'Dublin', 'Manchester', 'Aaarhus',
#        'Glendale', 'Sevilla', 'Brisbane', 'Strasbourg', 'Las Vegas',
#        'Oslo', 'Bergamo', 'Glen Waverly', 'Munich', 'Charleroi'],
# ...

# %%
data.COUNTRY.unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
data.DEALSIZE.unique()
# Out:
# array(['Small', 'Medium', 'Large'], dtype=object)

# %%
data.describe()
# Out:
#        QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER         SALES  \
# count      2823.000000  2823.000000      2823.000000   2823.000000
# mean         35.092809    83.658544         6.466171   3553.889072
# std           9.741443    20.174277         4.225841   1841.865106
# min           6.000000    26.880000         1.000000    482.130000
# 25%          27.000000    68.860000         3.000000   2203.430000
# 50%          35.000000    95.700000         6.000000   3184.800000
# 75%          43.000000   100.000000         9.000000   4508.000000
# max          97.000000   100.000000        18.000000  14082.800000
#
#             QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count  2823.000000  2823.000000  2823.00000  2823.000000
# mean      2.717676     7.092455  2003.81509   100.715551
# std       1.203878     3.656633     0.69967    40.187912
# min       1.000000     1.000000  2003.00000    33.000000
# 25%       2.000000     4.000000  2003.00000    68.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(data.QUANTITYORDERED)
# Out:
# (array([ 12., 459., 821., 785., 696.,  29.,  13.,   6.,   1.,   1.]),
#  array([ 6. , 15.1, 24.2, 33.3, 42.4, 51.5, 60.6, 69.7, 78.8, 87.9, 97. ]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
q1, q3 = np.percentile(data["QUANTITYORDERED"], [25,75])

# %%
iqr = q3 - q1
min_val = q1 - (iqr*1.5)
max_val = q3 + (iqr*1.5)

# %%
print(iqr)
print(q1)
print(q3)
print(min_val)
print(max_val)
# Out:
# 16.0
# 27.0
# 43.0
# 3.0
# 67.0

# %%
data = data.loc[(data["QUANTITYORDERED"] > min_val) & (data["QUANTITYORDERED"] < max_val)]

# %%
data
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES    STATUS  QTR_ID  \
# 0                  30      95.70                2  2871.00   Shipped       1
# 1                  34      81.35                5  2765.90   Shipped       2
# 2                  41      94.74                2  3884.34   Shipped       3
# 3                  45      83.26                6  3746.70   Shipped       3
# 4                  49     100.00               14  5205.27   Shipped       4
# ...               ...        ...              ...      ...       ...     ...
# 2818               20     100.00               15  2244.40   Shipped       4
# 2819               29     100.00                1  3978.51   Shipped       1
# 2820               43     100.00                4  5417.57  Resolved       1
# 2821               34      62.24                1  2116.16   Shipped       1
# 2822               47      65.52                9  3079.44   On Hold       2
#
# ...

# %%
data.to_csv(r'C:/Users/Harry/Portofolio/My Project/Data Cleaning/Salessamp Cleann.csv')
