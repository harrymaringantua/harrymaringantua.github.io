# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Harry/Portofolio/My Project/Data Cleaning/Dataset 4/County_Health_Rankings.csv")

# %%
data.head()
# Out:
#   State       County    State code  County code  Year span  \
# 0    US  United States         0.0          0.0  2003-2005
# 1    US  United States         0.0          0.0  2004-2006
# 2    US  United States         0.0          0.0  2005-2007
# 3    US  United States         0.0          0.0  2006-2008
# 4    US  United States         0.0          0.0  2007-2009
#
#          Measure name  Measure id    Numerator  Denominator   Raw value  \
# 0  Violent crime rate        43.0  1328750.667  274877117.0  483.398066
# 1  Violent crime rate        43.0  1340928.667  277612778.5  483.021233
# 2  Violent crime rate        43.0  1355853.167  280407694.7  483.529230
# 3  Violent crime rate        43.0  1366928.333  287614567.7  475.263942
# 4  Violent crime rate        43.0  1339439.333  292576281.2  457.808585
#
#    Confidence Interval Lower Bound  Confidence Interval Upper Bound  \
# 0                              NaN                              NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303864 entries, 0 to 303863
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   State                            303858 non-null  object
#  1     County                         303858 non-null  object
#  2   State code                       303860 non-null  float64
#  3   County code                      303860 non-null  float64
#  4   Year span                        303390 non-null  object
#  5   Measure name                     303390 non-null  object
#  6   Measure id                       303390 non-null  float64
#  7   Numerator                        214076 non-null  float64
#  8   Denominator                      184779 non-null  float64
#  9   Raw value                        289956 non-null  float64
#  10  Confidence Interval Lower Bound  189412 non-null  float64
# ...

# %%
data.columns
# Out:
# Index(['State', '  County  ', 'State code', 'County code', 'Year span',
#        'Measure name', 'Measure id', 'Numerator', 'Denominator', 'Raw value',
#        'Confidence Interval Lower Bound', 'Confidence Interval Upper Bound',
#        'Data Release Year', 'fipscode'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# State                                   6
#   County                                6
# State code                              4
# County code                             4
# Year span                             474
# Measure name                          474
# Measure id                            474
# Numerator                           89788
# Denominator                        119085
# Raw value                           13908
# Confidence Interval Lower Bound    114452
# Confidence Interval Upper Bound    114452
# Data Release Year                  153735
# fipscode                             9581
# dtype: int64

# %%
data = data.dropna()

# %%
data
# Out:
#        State         County    State code  County code Year span  \
# 156696    AL          Alabama         1.0          0.0      2009
# 156697    AL          Alabama         1.0          0.0      2010
# 156702    AL   Autauga County         1.0          1.0      2009
# 156703    AL   Autauga County         1.0          1.0      2010
# 156708    AL   Baldwin County         1.0          3.0      2009
# ...      ...              ...         ...          ...       ...
# 236736    WY  Washakie County        56.0         43.0      2009
# 236737    WY  Washakie County        56.0         43.0      2010
# 236742    WY    Weston County        56.0         45.0      2008
# 236743    WY    Weston County        56.0         45.0      2009
# 236744    WY    Weston County        56.0         45.0      2010
#
#          Measure name  Measure id  Numerator   Denominator  Raw value  \
# 156696      Uninsured        85.0  623621.00  3.947226e+06      0.158
# ...

# %%
data.isnull().sum()
# Out:
# State                              0
#   County                           0
# State code                         0
# County code                        0
# Year span                          0
# Measure name                       0
# Measure id                         0
# Numerator                          0
# Denominator                        0
# Raw value                          0
# Confidence Interval Lower Bound    0
# Confidence Interval Upper Bound    0
# Data Release Year                  0
# fipscode                           0
# dtype: int64

# %%
data.describe()
# Out:
#          State code   County code    Measure id     Numerator   Denominator  \
# count  25221.000000  25221.000000  25221.000000  2.522100e+04  2.522100e+04
# mean      30.307958    103.272907     51.755125  1.422441e+04  6.839887e+04
# std       15.130098    107.954138     32.005602  1.062027e+05  5.237876e+05
# min        1.000000      0.000000     11.000000  2.670000e+00  1.000000e+01
# 25%       18.000000     35.000000     11.000000  1.081100e+03  3.996805e+03
# 50%       29.000000     78.000000     70.000000  2.802000e+03  1.079200e+04
# 75%       45.000000    133.000000     85.000000  7.506000e+03  3.104332e+04
# max       56.000000    840.000000     85.000000  6.720279e+06  3.250429e+07
#
#           Raw value  Confidence Interval Lower Bound  \
# count  25221.000000                     25221.000000
# mean       0.261758                         0.218817
# std        0.067773                         0.055433
# min        0.033000                         0.029426
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.plot(kind = "line")
